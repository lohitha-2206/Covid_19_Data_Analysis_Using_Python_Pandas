# %% [markdown]
# # 🦠 Covid-19 Data Analysis using Python Pandas
#
# In this project, we will perform Data Analysis using Python and the Pandas library on a Covid-19 Dataset. The dataset contains information related to Confirmed Cases, Deaths, Recovered Cases, and different Regions affected by the Covid-19 pandemic.
#
# The main objective of this project is to understand how real-world Covid-19 data can be analyzed using Python. We will perform various operations like data cleaning, handling missing values, filtering records, statistical analysis, sorting data, grouping data, and extracting meaningful insights from the dataset.
#
# Using different Pandas functions and visualization libraries, we will analyze the dataset step by step and solve multiple real-time questions related to Covid-19 case analysis. This project also helps in understanding how Python is used in Data Science and Data Analytics for handling and analyzing structured datasets efficiently.
#
# ## Tools & Libraries Used
#
# - Python
# - Pandas
# - Seaborn
# - Matplotlib
# - Jupyter Notebook
#
# ## Pandas Functions & Methods Used
#
# - `import pandas as pd`
# - `pd.read_csv()`
# - `count()`
# - `isnull().sum()`
# - `groupby()`
# - `sort_values()`
# - `Filtering`
# - `sns.heatmap()`
# - `plt.show()`
#
# ## Operations Performed
#
# - Data Cleaning
# - Handling Missing Values
# - Heatmap Visualization
# - Filtering Records
# - GroupBy Operations
# - Sorting Data
# - Covid-19 Case Analysis
# - Statistical Analysis
# - Exploratory Data Analysis (EDA)
#
# ## Questions Solved in this Project
#
# 1. Show the number of Confirmed, Deaths, and Recovered cases in each Region.
# 2. Remove all the records where the Confirmed Cases are less than 10.
# 3. Find the Region with the maximum number of Confirmed cases.
# 4. Find the Region with the minimum number of Death cases.
# 5. Find the number of Confirmed, Deaths, and Recovered cases reported from India till 29 April 2020.
# 6. Sort the entire data with respect to:
#    - Confirmed cases in ascending order
#    - Recovered cases in descending order

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\DELL\Downloads\Covid_19_Data.csv")

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# ## 1) Show the number of Confirmed, Deaths and Recovered cases in each Region.

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').sum().head(20)
# Out:
#                                                                   Date  \
# Region
# Afghanistan                                                  4/29/2020
# Albania                                                      4/29/2020
# Algeria                                                      4/29/2020
# Andorra                                                      4/29/2020
# Angola                                                       4/29/2020
# Antigua and Barbuda                                          4/29/2020
# Argentina                                                    4/29/2020
# Armenia                                                      4/29/2020
# Australia            4/29/20204/29/20204/29/20204/29/20204/29/20204...
# Austria                                                      4/29/2020
# Azerbaijan                                                   4/29/2020
# Bahamas                                                      4/29/2020
# ...

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')[['Confirmed', 'Recovered']].sum()
# Out:
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %% [markdown]
# ## 2) Remove all the records where the Confirmed Cases is Less Than 10.

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data=data[~(data.Confirmed<10)]

# %%
data.head(20)
# Out:
#          Date State                  Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN             Afghanistan       1939      60        252
# 1   4/29/2020   NaN                 Albania        766      30        455
# 2   4/29/2020   NaN                 Algeria       3848     444       1702
# 3   4/29/2020   NaN                 Andorra        743      42        423
# 4   4/29/2020   NaN                  Angola         27       2          7
# 5   4/29/2020   NaN     Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN               Argentina       4285     214       1192
# 7   4/29/2020   NaN                 Armenia       1932      30        900
# 8   4/29/2020   NaN                 Austria      15402     580      12779
# 9   4/29/2020   NaN              Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                 Bahamas         80      11         23
# 11  4/29/2020   NaN                 Bahrain       2921       8       1455
# ...

# %% [markdown]
# ## 3) In which Region, maximum number of Confirmed cases were recorded ?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166536
# UK                 166432
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82861
# Brazil              79685
# Canada              52860
# Belgium             47859
# Netherlands         38993
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# ##  4) In which Region, minimum number of Deaths cases were recorded ?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending=True).head(20)
# Out:
# Region
# Cambodia                            0
# Fiji                                0
# Dominica                            0
# Central African Republic            0
# Eritrea                             0
# Laos                                0
# Holy See                            0
# Nepal                               0
# Madagascar                          0
# Macau                               0
# Mozambique                          0
# Mongolia                            0
# Namibia                             0
# Grenada                             0
# Saint Lucia                         0
# Saint Vincent and the Grenadines    0
# Timor-Leste                         0
# Uganda                              0
# Seychelles                          0
# South Sudan                         0
# Name: Deaths, dtype: int64

# %% [markdown]
# ## 5) How many Confirmed, Deaths & Recovered cases were reported from India till 29 April 2020 ?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data[data.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
data[data.Region == 'Yemen']
# Out:
# Empty DataFrame
# Columns: [Date, State, Region, Confirmed, Deaths, Recovered]
# Index: []

# %%
data[data.Region =='US']
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %% [markdown]
# ## 6-A ) Sort the entire data wrt No. of Confirmed cases in ascending order.

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.sort_values(by = ['Confirmed'], ascending = True).head(50)
# Out:
#           Date                         State  \
# 70   4/29/2020                           NaN
# 59   4/29/2020                           NaN
# 156  4/29/2020                           NaN
# 27   4/29/2020                           NaN
# 217  4/29/2020                     Greenland
# 318  4/29/2020                         Yukon
# 144  4/29/2020                           NaN
# 256  4/29/2020                    Montserrat
# 306  4/29/2020      Turks and Caicos Islands
# 206  4/29/2020   Falkland Islands (Malvinas)
# 215  4/29/2020                Grand Princess
# 118  4/29/2020                           NaN
# 270  4/29/2020      Northern Mariana Islands
# 136  4/29/2020                           NaN
# 45   4/29/2020                           NaN
# 201  4/29/2020                       Curacao
# 114  4/29/2020                           NaN
# 138  4/29/2020                           NaN
# 137  4/29/2020                           NaN
# 281  4/29/2020                       Qinghai
# ...

# %% [markdown]
# ##  6-B ) Sort the entire data wrt No. of Recovered cases in descending order.

# %%
data.sort_values( by = ['Recovered'], ascending = False).head(50)
# Out:
#           Date            State                Region  Confirmed  Deaths  \
# 153  4/29/2020              NaN                 Spain     236899   24275
# 61   4/29/2020              NaN               Germany     161539    6467
# 76   4/29/2020              NaN                  Iran      93657    5957
# 80   4/29/2020              NaN                 Italy     203591   27682
# 229  4/29/2020            Hubei        Mainland China      68128    4512
# 57   4/29/2020              NaN                France     165093   24087
# 167  4/29/2020              NaN                Turkey     117589    3081
# 22   4/29/2020              NaN                Brazil      79685    5513
# 158  4/29/2020              NaN           Switzerland      29407    1716
# 78   4/29/2020              NaN               Ireland      20253    1190
# 8    4/29/2020              NaN               Austria      15402     580
# 107  4/29/2020              NaN                Mexico      17799    1732
# ...
